# %% [markdown]
# # Projeto de Bases de Dados - Parte 3
#
# ### Docente Responsável
#
# Prof. Jorge Oliveira
#
# ### Grupo 30
# <dl>
#     <dt>HH horas (33.3%)</dt>
#     <dd>ist199970 João Maçãs</dd>
#     <dt>HH horas (33.3%)</dt>
#     <dd>ist1107369 Miguel Parece</dd>
#     <dt>HH horas (33.3%)</dt>
#     <dd>ist1102437 Tiago Caixinha</dd>
# <dl>
#
#
# Tirar os alter tables da r2 e r3 e substituir

# %%
# %load_ext sql
# %sql postgresql://p3:p3@postgres/p3

# %% [markdown]
# # Empresa de comércio online

# %% [markdown]
# ## 0. Carregamento da Base de Dados

# %% [markdown]
# Carregue o esquema de Base de Dados apresentado no Anexo A.

# %%
# %%sql
#
# DROP TABLE IF EXISTS customer CASCADE;
# DROP TABLE IF EXISTS orders CASCADE;
# DROP TABLE IF EXISTS pay CASCADE;
# DROP TABLE IF EXISTS employee CASCADE;
# DROP TABLE IF EXISTS process CASCADE;
# DROP TABLE IF EXISTS department CASCADE;
# DROP TABLE IF EXISTS workplace CASCADE;
# DROP TABLE IF EXISTS works CASCADE;
# DROP TABLE IF EXISTS office CASCADE;
# DROP TABLE IF EXISTS warehouse CASCADE;
# DROP TABLE IF EXISTS product CASCADE;
# DROP TABLE IF EXISTS contains CASCADE;
# DROP TABLE IF EXISTS supplier CASCADE;
# DROP TABLE IF EXISTS delivery CASCADE;
# DROP TABLE IF EXISTS data CASCADE;
#
# CREATE TABLE customer(
# cust_no INTEGER PRIMARY KEY,
# name VARCHAR(80) NOT NULL,
# email VARCHAR(254) UNIQUE NOT NULL,
# phone VARCHAR(15),
# address VARCHAR(255)
# );
#
# CREATE TABLE orders(
# order_no INTEGER PRIMARY KEY,
# cust_no INTEGER NOT NULL REFERENCES customer,
# date DATE NOT NULL
# --order_no must exist in contains
# );
#
# CREATE TABLE pay(
# order_no INTEGER PRIMARY KEY REFERENCES orders,
# cust_no INTEGER NOT NULL REFERENCES customer
# );
#
# CREATE TABLE employee(
# ssn VARCHAR(20) PRIMARY KEY,
# TIN VARCHAR(20) UNIQUE NOT NULL,
# bdate DATE,
# name VARCHAR NOT NULL
# --age must be >=18
# );
#
# CREATE TABLE process(
# ssn VARCHAR(20) REFERENCES employee,
# order_no INTEGER REFERENCES orders,
# PRIMARY KEY (ssn, order_no)
# );
#
# CREATE TABLE department(
# name VARCHAR PRIMARY KEY
# );
#
# CREATE TABLE workplace(
# address VARCHAR PRIMARY KEY,
# lat NUMERIC(8, 6) NOT NULL,
# long NUMERIC(9, 6) NOT NULL,
# UNIQUE(lat, long)
# --address must be in warehouse or office but not both
# );
#
# CREATE TABLE office(
# address VARCHAR(255) PRIMARY KEY REFERENCES workplace
# );
#
# CREATE TABLE warehouse(
# address VARCHAR(255) PRIMARY KEY REFERENCES workplace
# );
#
# CREATE TABLE works(
# ssn VARCHAR(20) REFERENCES employee,
# name VARCHAR(200) REFERENCES department,
# address VARCHAR(255) REFERENCES workplace,
# PRIMARY KEY (ssn, name, address)
# );
#
# CREATE TABLE product(
# SKU VARCHAR(25) PRIMARY KEY,
# name VARCHAR(200) NOT NULL,
# description VARCHAR,
# price NUMERIC(10, 2) NOT NULL,
# ean NUMERIC(13) UNIQUE
# );
#
# CREATE TABLE contains(
# order_no INTEGER REFERENCES orders,
# SKU VARCHAR(25) REFERENCES product,
# qty INTEGER,
# PRIMARY KEY (order_no, SKU)
# );
#
# CREATE TABLE supplier(
# TIN VARCHAR(20) PRIMARY KEY,
# name VARCHAR(200),
# address VARCHAR(255),
# SKU VARCHAR(25) REFERENCES product,
# date DATE
# );
#
# CREATE TABLE delivery(
# address VARCHAR(255) REFERENCES warehouse,
# TIN VARCHAR(20) REFERENCES supplier,
# PRIMARY KEY (address, TIN)
# );
# Out:
# *  postgresql://p3:***@postgres/p3
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# []

# %% [markdown]
# Crie as instruções para o seu preenchimento de forma consistente, garantindo que todas as consultas SQL e OLAP, apresentadas mais adiante, produzam um resultado não vazio.

# %%
# %%sql
#
# -- Populate customer table
# INSERT INTO customer (cust_no, name, email, phone, address)
# VALUES
#     (1, 'John Doe', 'john.doe@example.com', '1234567890', '123 Main St,5000-402 Vila Real'),
#     (2, 'Jane Smith', 'jane.smith@example.com', '9876543210', '456 Elm St,5000-402 Lisboa'),
#     (3, 'Mike Johnson', 'mike.johnson@example.com', '5555555555', '789 Oak St,5000-420 Porto');
#
# -- Populate orders table
# INSERT INTO orders (order_no, cust_no, date)
# VALUES
#     (1, 1, '2023-06-01'),
#     (2, 2, '2022-06-02'),
#     (3, 3, '2022-06-03'),
#     (4, 1, '2022-02-23'),
#     (5, 3, '2022-03-23'),
#     (6, 1, '2022-06-23'),
#     (7, 1, '2022-04-23'),
#     (8, 3, '2022-04-23'),
#     (9, 1, '2022-04-23'),
#     (10,3, '2022-04-23'),
#     (11, 2, '2022-07-23'),
#     (12, 3, '2022-07-23');
#
# -- Populate pay table
# INSERT INTO pay (order_no, cust_no)
# VALUES
#     (1, 1),
#     (2, 2),
#     (3, 3),
#     (4, 1),
#     (5, 3);
#
# -- Populate employee table
# INSERT INTO employee (ssn, TIN, bdate, name)
# VALUES
#     ('123456789', '987654321', '1990-06-11', 'John Smith'),
#     ('987654321', '123456789', '1985-02-02', 'Jane Doe'),
#     ('555555555', '111111111', '1995-03-03', 'Mike Johnson');
#
# -- Populate process table
# INSERT INTO process (ssn, order_no)
# VALUES
#     ('123456789', 1),
#     ('123456789', 2),
#     ('123456789', 3),
#     ('123456789', 4),
#     ('987654321', 2),
#     ('987654321', 3),
#     ('987654321', 4),
#     ('555555555', 3),
#     ('555555555', 1),
#     ('555555555', 2);
#
# -- Populate department table
# INSERT INTO department (name)
# VALUES
#     ('Sales'),
#     ('Marketing'),
#     ('HR');
#
# -- Populate workplace table
# INSERT INTO workplace (address, lat, long)
# VALUES
#     ('123 Main St', 40.123456, -75.123456),
#     ('456 Elm St', 41.654321, -76.654321),
#     ('789 Oak St', 42.987654, -77.987654),
#     ('Rua 1', 42.987654, -77.983654);
#
# -- Populate office table
# INSERT INTO office (address)
# VALUES
#     ('Rua 1');
#
# -- Populate warehouse table
# INSERT INTO warehouse (address)
# VALUES
#     ('123 Main St'),
#     ('456 Elm St'),
#     ('789 Oak St');
#
# -- Populate works table
# INSERT INTO works (ssn, name, address)
# VALUES
#     ('123456789', 'Sales', '123 Main St'),
#     ('987654321', 'Marketing', '456 Elm St'),
#     ('555555555', 'HR', '789 Oak St');
#
# -- Populate product table
# INSERT INTO product (SKU, name, description, price, ean)
# VALUES
#     ('SKU123', 'Product 1', 'Description 1', 10.99, 1234567890123),
#     ('SKU456', 'Product 2', 'Description 2', 19.99, 9876543210987),
#     ('SKU789', 'Product 3', 'Description 3', 5.99, 5555555555555);
#
# -- Populate contains table
# INSERT INTO contains (order_no, SKU, qty)
# VALUES
#     (1, 'SKU123', 2),
#     (1, 'SKU456', 1),
#     (2, 'SKU789', 3),
#     (3, 'SKU123', 1),
#     (5, 'SKU123', 2);
#
# -- Populate supplier table
# INSERT INTO supplier (TIN, name, address, SKU, date)
# VALUES
#     ('111111111', 'Supplier 1', '123 Supplier St', 'SKU123', '2023-05-01'),
#     ('222222222', 'Supplier 2', '456 Supplier St', 'SKU456', '2023-05-02'),
#     ('333333333', 'Supplier 3', '789 Supplier St', 'SKU789', '2023-05-03');
#
# -- Populate delivery table
# INSERT INTO delivery (address, TIN)
# VALUES
#     ('123 Main St', '111111111'),
#     ('456 Elm St', '222222222'),
#     ('789 Oak St', '333333333');
#
#
#
# CREATE OR REPLACE FUNCTION delete_cust (IN cust INT,OUT a VARCHAR)
# AS
# $$
# BEGIN
#     DELETE FROM contains WHERE order_no IN
#     (SELECT order_no FROM orders WHERE  cust_no = cust);
#     DELETE FROM process pr WHERE order_no IN
#     (SELECT order_no FROM orders WHERE cust_no = cust);
#     DELETE FROM pay p WHERE p.cust_no = cust;
#     DELETE FROM orders o WHERE o.cust_no=cust;
#     DELETE FROM customer c WHERE c.cust_no=cust;
#     RETURN;
# END
# $$
# LANGUAGE plpgsql;
# Out:
# *  postgresql://p3:***@postgres/p3
# 3 rows affected.
# 12 rows affected.
# 5 rows affected.
# 3 rows affected.
# 10 rows affected.
# 3 rows affected.
# 4 rows affected.
# 1 rows affected.
# 3 rows affected.
# 3 rows affected.
# 3 rows affected.
# 5 rows affected.
# 3 rows affected.
# 3 rows affected.
# Done.
# []

# %% [markdown]
# ## 1. Restrições de Integridade
#
# Apresente o código para implementar as seguintes restrições de integridade, se necessário, com recurso a extensões procedimentais SQL (Stored Procedures e Triggers):

# %% [markdown]
# (RI-1) Nenhum empregado pode ter menos de 18 anos de idade

# %%
# %%sql
# ALTER TABLE employee
# ADD CONSTRAINT check_age CHECK (
#     date_part('year', age(NOW()::date, bdate)) -
#       CASE WHEN extract(month from NOW()::date) < extract(month from bdate)
#             OR (extract(month from NOW()::date) = extract(month from bdate)
#                 AND extract(day from NOW()::date) < extract(day from bdate))
#            THEN 1
#            ELSE 0
#       END >= 18
#   );
# Out:
# *  postgresql://p3:***@postgres/p3
# Done.
# []

# %% [markdown]
# (RI-2) Um 'Workplace' é obrigatoriamente um 'Office' ou 'Warehouse' mas não pode ser ambos

# %%
# %%sql
# CREATE OR REPLACE FUNCTION insert_warehouse_func() RETURNS TRIGGER AS
# $$
# BEGIN
#     IF NEW.address IN (SELECT address FROM office) THEN
#         RAISE EXCEPTION 'Address % is from an office.', NEW.address;
#     END IF;
#     RETURN NEW;
# END;
# $$ LANGUAGE plpgsql;
#
# CREATE OR REPLACE TRIGGER insert_warehouse_trigger BEFORE INSERT ON warehouse
# FOR EACH ROW EXECUTE FUNCTION insert_warehouse_func();
#
#
# CREATE OR REPLACE FUNCTION remove_office_warehouse_func() RETURNS TRIGGER AS
# $$
# BEGIN
#     IF OLD.address IN (SELECT address FROM workplace) THEN
#         RAISE EXCEPTION 'You need to remove the office/warehouse from workplace';
#     END IF;
#     RETURN NEW;
# END;
# $$ LANGUAGE plpgsql;
#
# CREATE CONSTRAINT TRIGGER remove_office_warehouse_trigger AFTER DELETE ON office
# DEFERRABLE INITIALLY DEFERRED
# FOR EACH ROW EXECUTE FUNCTION remove_office_warehouse_func();
#
# CREATE CONSTRAINT TRIGGER remove_office_warehouse_trigger AFTER DELETE ON warehouse
# DEFERRABLE INITIALLY DEFERRED
# FOR EACH ROW EXECUTE FUNCTION remove_office_warehouse_func();
#
# CREATE OR REPLACE FUNCTION insert_office_func() RETURNS TRIGGER AS
# $$
# BEGIN
#     IF NEW.address IN (SELECT address FROM warehouse) THEN
#         RAISE EXCEPTION 'Address % is from a warehouse.', NEW.address;
#     END IF;
#     RETURN NEW;
# END;
# $$ LANGUAGE plpgsql;
#
# CREATE OR REPLACE TRIGGER insert_office_trigger BEFORE INSERT ON office
# FOR EACH ROW EXECUTE FUNCTION insert_office_func();
#
# CREATE OR REPLACE FUNCTION insert_workplace_func() RETURNS TRIGGER AS
# $$
# BEGIN
#     IF NEW.address NOT IN (SELECT address FROM warehouse UNION SELECT address FROM office) THEN
#         RAISE EXCEPTION 'Address % isnt a warehouse or an office', NEW.address;
#     END IF;
#     RETURN NEW;
# END;
# $$ LANGUAGE plpgsql;
#
# --CREATE OR REPLACE FUNCTION remove_workplace_func() RETURNS TRIGGER AS
# --$$
# --BEGIN
# --    IF OLD.address IN (SELECT address FROM warehouse UNION SELECT address FROM office) THEN
# --        RAISE EXCEPTION 'Address % is still a warehouse or office', OLD.address;
# --    END IF;
# --    RETURN NEW;
# --END;
# --$$LANGUAGE plpgsql;
#
# CREATE CONSTRAINT TRIGGER remove_workplace_trigger AFTER DELETE ON workplace
# DEFERRABLE INITIALLY DEFERRED
# FOR EACH ROW EXECUTE FUNCTION remove_workplace_func();
#
# CREATE CONSTRAINT TRIGGER insert_workplace_trigger AFTER INSERT ON workplace
# DEFERRABLE INITIALLY DEFERRED
# FOR EACH ROW EXECUTE FUNCTION insert_workplace_func();
# Out:
# *  postgresql://p3:***@postgres/p3
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# []

# %% [markdown]
# (RI-3) Uma 'Order' tem de figurar obrigatoriamente em 'Contains'.

# %%
# %%sql
#
# CREATE OR REPLACE FUNCTION remove_contains_func() RETURNS TRIGGER AS
# $$
# BEGIN
#     IF OLD.order_no IN (SELECT order_no FROM orders) THEN
#         RAISE EXCEPTION 'You need to remove the order from orders';
#     END IF;
#     RETURN NEW;
# END;
# $$ LANGUAGE plpgsql;
#
# CREATE CONSTRAINT TRIGGER remove_contains_trigger AFTER DELETE ON contains
# DEFERRABLE INITIALLY DEFERRED
# FOR EACH ROW EXECUTE FUNCTION remove_contains_func();
#
#
#
# CREATE OR REPLACE FUNCTION insert_order_func() RETURNS TRIGGER AS
# $$
# BEGIN
#     IF NEW.order_no NOT IN (SELECT order_no FROM contains) THEN
#         RAISE EXCEPTION 'Order % doesnt have products.', NEW.order_no;
#     END IF;
#     RETURN NEW;
# END;
# $$ LANGUAGE plpgsql;
#
# CREATE CONSTRAINT TRIGGER insert_order_trigger AFTER INSERT ON orders
# DEFERRABLE INITIALLY DEFERRED
# FOR EACH ROW EXECUTE FUNCTION insert_order_func();
# Out:
# *  postgresql://p3:***@postgres/p3
# Done.
# Done.
# Done.
# Done.
# []

# %% [markdown]
# ## 2. Consultas SQL

# %% [markdown]
# Apresente a consulta SQL mais sucinta para cada uma das seguintes questões

# %% [markdown]
# 1) Qual o número e nome do(s) cliente(s) com maior valor total de encomendas pagas?

# %%
# %%sql
#
# SELECT c.cust_no, c.name
# FROM customer c
#     JOIN pay USING (cust_no)
#     JOIN contains USING (order_no)
#     JOIN product USING(sku)
# GROUP BY c.cust_no
# HAVING SUM(price*qty)>=ALL(
#     SELECT SUM(p1.price*co1.qty)
#     FROM customer c1
#         JOIN pay USING (cust_no)
#         JOIN contains co1 USING (order_no)
#         JOIN product p1 USING (sku)
#     GROUP BY c1.cust_no
# );
# Out:
# *  postgresql://p3:***@postgres/p3
# 1 rows affected.
# [(1, 'John Doe')]

# %% [markdown]
# 2. Qual o nome dos empregados que processaram encomendas em todos os dias de 2022 em que houve encomendas?

# %%
# %%sql
# SELECT DISTINCT e.name
# FROM employee e
# WHERE NOT EXISTS(
#     SELECT order_no
#     FROM orders
#     WHERE EXTRACT(YEAR FROM date)=2022
#     EXCEPT
#     SELECT order_no
#     FROM process p
#         JOIN orders USING (order_no)
#     WHERE p.ssn = e.ssn
# );
# Out:
# *  postgresql://p3:***@postgres/p3
# 0 rows affected.
# []

# %% [markdown]
# 3. Quantas encomendas foram realizadas mas não pagas em cada mês de 2022?

# %%
# %%sql
# SELECT TO_CHAR(dates.month, 'Month') AS month, COUNT(orders.order_no) AS total_orders
# FROM (
#   SELECT generate_series(
#     '2022-01-01'::date,
#     '2022-12-31'::date,
#     '1 month'::interval
#   ) AS month
# ) AS dates
# LEFT JOIN orders ON TO_CHAR(orders.date, 'YYYY-MM') = TO_CHAR(dates.month, 'YYYY-MM')
# LEFT JOIN pay p USING (order_no)
# WHERE EXTRACT(YEAR FROM dates.month) = 2022 AND (p.cust_no IS NULL)
# GROUP BY TO_CHAR(dates.month, 'Month')
# ORDER BY MIN(dates.month);
# Out:
# *  postgresql://p3:***@postgres/p3
# 11 rows affected.
# [('January  ', 0),
#  ('March    ', 1),
#  ('April    ', 4),
#  ('May      ', 0),
#  ('June     ', 1),
#  ('July     ', 2),
#  ('August   ', 0),
#  ('September', 0),
#  ('October  ', 0),
#  ('November ', 0),
#  ('December ', 0)]

# %% [markdown]
# ## 3. Vistas

# %% [markdown]
# Crie uma vista que resuma as informações mais importantes sobre as vendas de produtos, combinando informações de diferentes tabelas do esquema de base de dados. A vista deve ter o seguinte esquema:
#
# product_sales(sku, order_no, qty, total_price, year, month, day_of_month, day_of_week, city)

# %%
# %%sql
#
# CREATE VIEW product_sales AS
# SELECT sku, order_no, qty, SUM(qty*price) AS total_price, EXTRACT(YEAR FROM date) AS year, EXTRACT(MONTH FROM date) as month, EXTRACT(DAY FROM date) AS day_of_month, EXTRACT(DOW FROM date) as day_of_week, SUBSTRING(address, '[0-9]{4}-[0-9]{3}\s+(.*)$') AS city
# FROM contains
#     JOIN orders USING (order_no)
#     JOIN product USING (sku)
#     JOIN customer USING (cust_no)
# GROUP BY (sku,order_no,date,address)
# ORDER BY (qty) DESC;
#
# SELECT * FROM product_sales;
# Out:
# *  postgresql://p3:***@postgres/p3
# Done.
# Done.
# 5 rows affected.
# [('SKU789', 2, 3, Decimal('17.97'), Decimal('2022'), 'June     ', Decimal('2'), 'Thursday ', 'Lisboa'),
#  ('SKU123', 5, 2, Decimal('21.98'), Decimal('2022'), 'March    ', Decimal('23'), 'Wednesday', 'Porto'),
#  ('SKU123', 1, 2, Decimal('21.98'), Decimal('2023'), 'June     ', Decimal('1'), 'Thursday ', 'Vila Real'),
#  ('SKU123', 3, 1, Decimal('10.99'), Decimal('2022'), 'June     ', Decimal('3'), 'Friday   ', 'Porto'),
#  ('SKU456', 1, 1, Decimal('19.99'), Decimal('2023'), 'June     ', Decimal('1'), 'Thursday ', 'Vila Real')]

# %% [markdown]
# ## 4. Desenvolvimento de Aplicação

# %% [markdown]
# ### Explicação da arquitetura da aplicação web, incluindo um link para uma versão de trabalho e as relações entre os vários ficheiros na pasta web/arquivos
#
# ...

# %% [markdown]
# ## 5. Consultas OLAP

# %% [markdown]
# Usando a vista desenvolvida para a Questão 3, escreva duas consultas SQL que permitam analisar:

# %% [markdown]
# 1. As quantidade e valores totais de venda de cada produto em 2022, globalmente, por cidade, por mês, dia do mês e dia da semana

# %%
# %%sql
#
# DROP TABLE data;
# CREATE TABLE data(
# id SERIAL PRIMARY KEY,
# year INTEGER,
# month INTEGER,
# weekday INTEGER,
# day INTEGER
# );
#
# INSERT INTO data (year, month, weekday, day)
# SELECT EXTRACT(YEAR FROM dd),
#        EXTRACT(MONTH FROM dd),
#        EXTRACT(DOW FROM dd),
#        EXTRACT(DAY FROM dd)
# FROM GENERATE_SERIES(
#    '2022-01-01',
#    '2022-12-31',
#    '1 day'::INTERVAL
# ) AS dd;
#
#
#
# SELECT p.sku, ps.city, to_char(DATE_TRUNC('month', TIMESTAMP '01-01-2022') + INTERVAL '1 month' * (d.month - 1), 'Month'), d.day, to_char('2022-01-03'::date + (d.weekday - 1) * INTERVAL '1 day', 'Day'), SUM(COALESCE(total_price,0)) AS total_value
# FROM (
#     SELECT DISTINCT sku
#     FROM product_sales
# ) p
# CROSS JOIN data d
# LEFT JOIN product_sales ps ON d.year = ps.year
#                             AND d.month = ps.month
#                             AND d.day = ps.day_of_month
#                             AND p.sku = ps.sku
#                             AND d.weekday = ps.day_of_week
#                             AND ps.year =2022
# WHERE d.year = 2022
# GROUP BY GROUPING SETS ((p.sku),(p.sku,ps.city), (p.sku,d.month), (p.sku,d.month,d.day), (p.sku,d.weekday))
# ORDER BY (p.sku,ps.city,d.month,d.day,d.weekday)
# Out:
# *  postgresql://p3:***@postgres/p3
# Done.
# Done.
# 365 rows affected.
# 1160 rows affected.
# [('SKU123', 'Porto', None, None, None, Decimal('32.97')),
#  ('SKU123', None, 'January  ', 1, None, Decimal('0')),
#  ('SKU123', None, 'January  ', 2, None, Decimal('0')),
#  ('SKU123', None, 'January  ', 3, None, Decimal('0')),
#  ('SKU123', None, 'January  ', 4, None, Decimal('0')),
#  ('SKU123', None, 'January  ', 5, None, Decimal('0')),
#  ('SKU123', None, 'January  ', 6, None, Decimal('0')),
#  ('SKU123', None, 'January  ', 7, None, Decimal('0')),
#  ('SKU123', None, 'January  ', 8, None, Decimal('0')),
#  ('SKU123', None, 'January  ', 9, None, Decimal('0')),
#  ('SKU123', None, 'January  ', 10, None, Decimal('0')),
#  ('SKU123', None, 'January  ', 11, None, Decimal('0')),
#  ('SKU123', None, 'January  ', 12, None, Decimal('0')),
#  ('SKU123', None, 'January  ', 13, None, Decimal('0')),
#  ('SKU123', None, 'January  ', 14, None, Decimal('0')),
#  ('SKU123', None, 'January  ', 15, None, Decimal('0')),
#  ('SKU123', None, 'January  ', 16, None, Decimal('0')),
#  ('SKU123', None, 'January  ', 17, None, Decimal('0')),
#  ('SKU123', None, 'January  ', 18, None, Decimal('0')),
#  ('SKU123', None, 'January  ', 19, None, Decimal('0')),
#  ('SKU123', None, 'January  ', 20, None, Decimal('0')),
#  ('SKU123', None, 'January  ', 21, None, Decimal('0')),
#  ('SKU123', None, 'January  ', 22, None, Decimal('0')),
#  ('SKU123', None, 'January  ', 23, None, Decimal('0')),
#  ('SKU123', None, 'January  ', 24, None, Decimal('0')),
#  ('SKU123', None, 'January  ', 25, None, Decimal('0')),
#  ('SKU123', None, 'January  ', 26, None, Decimal('0')),
#  ('SKU123', None, 'January  ', 27, None, Decimal('0')),
#  ('SKU123', None, 'January  ', 28, None, Decimal('0')),
#  ('SKU123', None, 'January  ', 29, None, Decimal('0')),
#  ('SKU123', None, 'January  ', 30, None, Decimal('0')),
#  ('SKU123', None, 'January  ', 31, None, Decimal('0')),
#  ('SKU123', None, 'January  ', None, None, Decimal('0')),
#  ('SKU123', None, 'February ', 1, None, Decimal('0')),
#  ('SKU123', None, 'February ', 2, None, Decimal('0')),
#  ('SKU123', None, 'February ', 3, None, Decimal('0')),
#  ('SKU123', None, 'February ', 4, None, Decimal('0')),
#  ('SKU123', None, 'February ', 5, None, Decimal('0')),
#  ('SKU123', None, 'February ', 6, None, Decimal('0')),
#  ('SKU123', None, 'February ', 7, None, Decimal('0')),
#  ('SKU123', None, 'February ', 8, None, Decimal('0')),
#  ('SKU123', None, 'February ', 9, None, Decimal('0')),
#  ('SKU123', None, 'February ', 10, None, Decimal('0')),
#  ('SKU123', None, 'February ', 11, None, Decimal('0')),
#  ('SKU123', None, 'February ', 12, None, Decimal('0')),
#  ('SKU123', None, 'February ', 13, None, Decimal('0')),
#  ('SKU123', None, 'February ', 14, None, Decimal('0')),
#  ('SKU123', None, 'February ', 15, None, Decimal('0')),
#  ('SKU123', None, 'February ', 16, None, Decimal('0')),
#  ('SKU123', None, 'February ', 17, None, Decimal('0')),
#  ('SKU123', None, 'February ', 18, None, Decimal('0')),
#  ('SKU123', None, 'February ', 19, None, Decimal('0')),
#  ('SKU123', None, 'February ', 20, None, Decimal('0')),
#  ('SKU123', None, 'February ', 21, None, Decimal('0')),
#  ('SKU123', None, 'February ', 22, None, Decimal('0')),
#  ('SKU123', None, 'February ', 23, None, Decimal('0')),
#  ('SKU123', None, 'February ', 24, None, Decimal('0')),
#  ('SKU123', None, 'February ', 25, None, Decimal('0')),
#  ('SKU123', None, 'February ', 26, None, Decimal('0')),
#  ('SKU123', None, 'February ', 27, None, Decimal('0')),
#  ('SKU123', None, 'February ', 28, None, Decimal('0')),
#  ('SKU123', None, 'February ', None, None, Decimal('0')),
#  ('SKU123', None, 'March    ', 1, None, Decimal('0')),
#  ('SKU123', None, 'March    ', 2, None, Decimal('0')),
#  ('SKU123', None, 'March    ', 3, None, Decimal('0')),
#  ('SKU123', None, 'March    ', 4, None, Decimal('0')),
#  ('SKU123', None, 'March    ', 5, None, Decimal('0')),
#  ('SKU123', None, 'March    ', 6, None, Decimal('0')),
#  ('SKU123', None, 'March    ', 7, None, Decimal('0')),
#  ('SKU123', None, 'March    ', 8, None, Decimal('0')),
#  ('SKU123', None, 'March    ', 9, None, Decimal('0')),
#  ('SKU123', None, 'March    ', 10, None, Decimal('0')),
#  ('SKU123', None, 'March    ', 11, None, Decimal('0')),
#  ('SKU123', None, 'March    ', 12, None, Decimal('0')),
#  ('SKU123', None, 'March    ', 13, None, Decimal('0')),
#  ('SKU123', None, 'March    ', 14, None, Decimal('0')),
#  ('SKU123', None, 'March    ', 15, None, Decimal('0')),
#  ('SKU123', None, 'March    ', 16, None, Decimal('0')),
#  ('SKU123', None, 'March    ', 17, None, Decimal('0')),
#  ('SKU123', None, 'March    ', 18, None, Decimal('0')),
#  ('SKU123', None, 'March    ', 19, None, Decimal('0')),
#  ('SKU123', None, 'March    ', 20, None, Decimal('0')),
#  ('SKU123', None, 'March    ', 21, None, Decimal('0')),
#  ('SKU123', None, 'March    ', 22, None, Decimal('0')),
#  ('SKU123', None, 'March    ', 23, None, Decimal('21.98')),
#  ('SKU123', None, 'March    ', 24, None, Decimal('0')),
#  ('SKU123', None, 'March    ', 25, None, Decimal('0')),
#  ('SKU123', None, 'March    ', 26, None, Decimal('0')),
#  ('SKU123', None, 'March    ', 27, None, Decimal('0')),
#  ('SKU123', None, 'March    ', 28, None, Decimal('0')),
#  ('SKU123', None, 'March    ', 29, None, Decimal('0')),
#  ('SKU123', None, 'March    ', 30, None, Decimal('0')),
#  ('SKU123', None, 'March    ', 31, None, Decimal('0')),
#  ('SKU123', None, 'March    ', None, None, Decimal('21.98')),
#  ('SKU123', None, 'April    ', 1, None, Decimal('0')),
#  ('SKU123', None, 'April    ', 2, None, Decimal('0')),
#  ('SKU123', None, 'April    ', 3, None, Decimal('0')),
#  ('SKU123', None, 'April    ', 4, None, Decimal('0')),
#  ('SKU123', None, 'April    ', 5, None, Decimal('0')),
#  ('SKU123', None, 'April    ', 6, None, Decimal('0')),
#  ('SKU123', None, 'April    ', 7, None, Decimal('0')),
#  ('SKU123', None, 'April    ', 8, None, Decimal('0')),
#  ('SKU123', None, 'April    ', 9, None, Decimal('0')),
#  ('SKU123', None, 'April    ', 10, None, Decimal('0')),
#  ('SKU123', None, 'April    ', 11, None, Decimal('0')),
#  ('SKU123', None, 'April    ', 12, None, Decimal('0')),
#  ('SKU123', None, 'April    ', 13, None, Decimal('0')),
#  ('SKU123', None, 'April    ', 14, None, Decimal('0')),
#  ('SKU123', None, 'April    ', 15, None, Decimal('0')),
#  ('SKU123', None, 'April    ', 16, None, Decimal('0')),
#  ('SKU123', None, 'April    ', 17, None, Decimal('0')),
#  ('SKU123', None, 'April    ', 18, None, Decimal('0')),
#  ('SKU123', None, 'April    ', 19, None, Decimal('0')),
#  ('SKU123', None, 'April    ', 20, None, Decimal('0')),
#  ('SKU123', None, 'April    ', 21, None, Decimal('0')),
#  ('SKU123', None, 'April    ', 22, None, Decimal('0')),
#  ('SKU123', None, 'April    ', 23, None, Decimal('0')),
#  ('SKU123', None, 'April    ', 24, None, Decimal('0')),
#  ('SKU123', None, 'April    ', 25, None, Decimal('0')),
#  ('SKU123', None, 'April    ', 26, None, Decimal('0')),
#  ('SKU123', None, 'April    ', 27, None, Decimal('0')),
#  ('SKU123', None, 'April    ', 28, None, Decimal('0')),
#  ('SKU123', None, 'April    ', 29, None, Decimal('0')),
#  ('SKU123', None, 'April    ', 30, None, Decimal('0')),
#  ('SKU123', None, 'April    ', None, None, Decimal('0')),
#  ('SKU123', None, 'May      ', 1, None, Decimal('0')),
#  ('SKU123', None, 'May      ', 2, None, Decimal('0')),
#  ('SKU123', None, 'May      ', 3, None, Decimal('0')),
#  ('SKU123', None, 'May      ', 4, None, Decimal('0')),
#  ('SKU123', None, 'May      ', 5, None, Decimal('0')),
#  ('SKU123', None, 'May      ', 6, None, Decimal('0')),
#  ('SKU123', None, 'May      ', 7, None, Decimal('0')),
#  ('SKU123', None, 'May      ', 8, None, Decimal('0')),
#  ('SKU123', None, 'May      ', 9, None, Decimal('0')),
#  ('SKU123', None, 'May      ', 10, None, Decimal('0')),
#  ('SKU123', None, 'May      ', 11, None, Decimal('0')),
#  ('SKU123', None, 'May      ', 12, None, Decimal('0')),
#  ('SKU123', None, 'May      ', 13, None, Decimal('0')),
#  ('SKU123', None, 'May      ', 14, None, Decimal('0')),
#  ('SKU123', None, 'May      ', 15, None, Decimal('0')),
#  ('SKU123', None, 'May      ', 16, None, Decimal('0')),
#  ('SKU123', None, 'May      ', 17, None, Decimal('0')),
#  ('SKU123', None, 'May      ', 18, None, Decimal('0')),
#  ('SKU123', None, 'May      ', 19, None, Decimal('0')),
#  ('SKU123', None, 'May      ', 20, None, Decimal('0')),
#  ('SKU123', None, 'May      ', 21, None, Decimal('0')),
#  ('SKU123', None, 'May      ', 22, None, Decimal('0')),
#  ('SKU123', None, 'May      ', 23, None, Decimal('0')),
#  ('SKU123', None, 'May      ', 24, None, Decimal('0')),
#  ('SKU123', None, 'May      ', 25, None, Decimal('0')),
#  ('SKU123', None, 'May      ', 26, None, Decimal('0')),
#  ('SKU123', None, 'May      ', 27, None, Decimal('0')),
#  ('SKU123', None, 'May      ', 28, None, Decimal('0')),
#  ('SKU123', None, 'May      ', 29, None, Decimal('0')),
#  ('SKU123', None, 'May      ', 30, None, Decimal('0')),
#  ('SKU123', None, 'May      ', 31, None, Decimal('0')),
#  ('SKU123', None, 'May      ', None, None, Decimal('0')),
#  ('SKU123', None, 'June     ', 1, None, Decimal('0')),
#  ('SKU123', None, 'June     ', 2, None, Decimal('0')),
#  ('SKU123', None, 'June     ', 3, None, Decimal('10.99')),
#  ('SKU123', None, 'June     ', 4, None, Decimal('0')),
#  ('SKU123', None, 'June     ', 5, None, Decimal('0')),
#  ('SKU123', None, 'June     ', 6, None, Decimal('0')),
#  ('SKU123', None, 'June     ', 7, None, Decimal('0')),
#  ('SKU123', None, 'June     ', 8, None, Decimal('0')),
#  ('SKU123', None, 'June     ', 9, None, Decimal('0')),
#  ('SKU123', None, 'June     ', 10, None, Decimal('0')),
#  ('SKU123', None, 'June     ', 11, None, Decimal('0')),
#  ('SKU123', None, 'June     ', 12, None, Decimal('0')),
#  ('SKU123', None, 'June     ', 13, None, Decimal('0')),
#  ('SKU123', None, 'June     ', 14, None, Decimal('0')),
#  ('SKU123', None, 'June     ', 15, None, Decimal('0')),
#  ('SKU123', None, 'June     ', 16, None, Decimal('0')),
#  ('SKU123', None, 'June     ', 17, None, Decimal('0')),
#  ('SKU123', None, 'June     ', 18, None, Decimal('0')),
#  ('SKU123', None, 'June     ', 19, None, Decimal('0')),
#  ('SKU123', None, 'June     ', 20, None, Decimal('0')),
#  ('SKU123', None, 'June     ', 21, None, Decimal('0')),
#  ('SKU123', None, 'June     ', 22, None, Decimal('0')),
#  ('SKU123', None, 'June     ', 23, None, Decimal('0')),
#  ('SKU123', None, 'June     ', 24, None, Decimal('0')),
#  ('SKU123', None, 'June     ', 25, None, Decimal('0')),
#  ('SKU123', None, 'June     ', 26, None, Decimal('0')),
#  ('SKU123', None, 'June     ', 27, None, Decimal('0')),
#  ('SKU123', None, 'June     ', 28, None, Decimal('0')),
#  ('SKU123', None, 'June     ', 29, None, Decimal('0')),
#  ('SKU123', None, 'June     ', 30, None, Decimal('0')),
#  ('SKU123', None, 'June     ', None, None, Decimal('10.99')),
#  ('SKU123', None, 'July     ', 1, None, Decimal('0')),
#  ('SKU123', None, 'July     ', 2, None, Decimal('0')),
#  ('SKU123', None, 'July     ', 3, None, Decimal('0')),
#  ('SKU123', None, 'July     ', 4, None, Decimal('0')),
#  ('SKU123', None, 'July     ', 5, None, Decimal('0')),
#  ('SKU123', None, 'July     ', 6, None, Decimal('0')),
#  ('SKU123', None, 'July     ', 7, None, Decimal('0')),
#  ('SKU123', None, 'July     ', 8, None, Decimal('0')),
#  ('SKU123', None, 'July     ', 9, None, Decimal('0')),
#  ('SKU123', None, 'July     ', 10, None, Decimal('0')),
#  ('SKU123', None, 'July     ', 11, None, Decimal('0')),
#  ('SKU123', None, 'July     ', 12, None, Decimal('0')),
#  ('SKU123', None, 'July     ', 13, None, Decimal('0')),
#  ('SKU123', None, 'July     ', 14, None, Decimal('0')),
#  ('SKU123', None, 'July     ', 15, None, Decimal('0')),
#  ('SKU123', None, 'July     ', 16, None, Decimal('0')),
#  ('SKU123', None, 'July     ', 17, None, Decimal('0')),
#  ('SKU123', None, 'July     ', 18, None, Decimal('0')),
#  ('SKU123', None, 'July     ', 19, None, Decimal('0')),
#  ('SKU123', None, 'July     ', 20, None, Decimal('0')),
#  ('SKU123', None, 'July     ', 21, None, Decimal('0')),
#  ('SKU123', None, 'July     ', 22, None, Decimal('0')),
#  ('SKU123', None, 'July     ', 23, None, Decimal('0')),
#  ('SKU123', None, 'July     ', 24, None, Decimal('0')),
#  ('SKU123', None, 'July     ', 25, None, Decimal('0')),
#  ('SKU123', None, 'July     ', 26, None, Decimal('0')),
#  ('SKU123', None, 'July     ', 27, None, Decimal('0')),
#  ('SKU123', None, 'July     ', 28, None, Decimal('0')),
#  ('SKU123', None, 'July     ', 29, None, Decimal('0')),
#  ('SKU123', None, 'July     ', 30, None, Decimal('0')),
#  ('SKU123', None, 'July     ', 31, None, Decimal('0')),
#  ('SKU123', None, 'July     ', None, None, Decimal('0')),
#  ('SKU123', None, 'August   ', 1, None, Decimal('0')),
#  ('SKU123', None, 'August   ', 2, None, Decimal('0')),
#  ('SKU123', None, 'August   ', 3, None, Decimal('0')),
#  ('SKU123', None, 'August   ', 4, None, Decimal('0')),
#  ('SKU123', None, 'August   ', 5, None, Decimal('0')),
#  ('SKU123', None, 'August   ', 6, None, Decimal('0')),
#  ('SKU123', None, 'August   ', 7, None, Decimal('0')),
#  ('SKU123', None, 'August   ', 8, None, Decimal('0')),
#  ('SKU123', None, 'August   ', 9, None, Decimal('0')),
#  ('SKU123', None, 'August   ', 10, None, Decimal('0')),
#  ('SKU123', None, 'August   ', 11, None, Decimal('0')),
#  ('SKU123', None, 'August   ', 12, None, Decimal('0')),
#  ('SKU123', None, 'August   ', 13, None, Decimal('0')),
#  ('SKU123', None, 'August   ', 14, None, Decimal('0')),
#  ('SKU123', None, 'August   ', 15, None, Decimal('0')),
#  ('SKU123', None, 'August   ', 16, None, Decimal('0')),
#  ('SKU123', None, 'August   ', 17, None, Decimal('0')),
#  ('SKU123', None, 'August   ', 18, None, Decimal('0')),
#  ('SKU123', None, 'August   ', 19, None, Decimal('0')),
#  ('SKU123', None, 'August   ', 20, None, Decimal('0')),
#  ('SKU123', None, 'August   ', 21, None, Decimal('0')),
#  ('SKU123', None, 'August   ', 22, None, Decimal('0')),
#  ('SKU123', None, 'August   ', 23, None, Decimal('0')),
#  ('SKU123', None, 'August   ', 24, None, Decimal('0')),
#  ('SKU123', None, 'August   ', 25, None, Decimal('0')),
#  ('SKU123', None, 'August   ', 26, None, Decimal('0')),
#  ('SKU123', None, 'August   ', 27, None, Decimal('0')),
#  ('SKU123', None, 'August   ', 28, None, Decimal('0')),
#  ('SKU123', None, 'August   ', 29, None, Decimal('0')),
#  ('SKU123', None, 'August   ', 30, None, Decimal('0')),
#  ('SKU123', None, 'August   ', 31, None, Decimal('0')),
#  ('SKU123', None, 'August   ', None, None, Decimal('0')),
#  ('SKU123', None, 'September', 1, None, Decimal('0')),
#  ('SKU123', None, 'September', 2, None, Decimal('0')),
#  ('SKU123', None, 'September', 3, None, Decimal('0')),
#  ('SKU123', None, 'September', 4, None, Decimal('0')),
#  ('SKU123', None, 'September', 5, None, Decimal('0')),
#  ('SKU123', None, 'September', 6, None, Decimal('0')),
#  ('SKU123', None, 'September', 7, None, Decimal('0')),
#  ('SKU123', None, 'September', 8, None, Decimal('0')),
#  ('SKU123', None, 'September', 9, None, Decimal('0')),
#  ('SKU123', None, 'September', 10, None, Decimal('0')),
#  ('SKU123', None, 'September', 11, None, Decimal('0')),
#  ('SKU123', None, 'September', 12, None, Decimal('0')),
#  ('SKU123', None, 'September', 13, None, Decimal('0')),
#  ('SKU123', None, 'September', 14, None, Decimal('0')),
#  ('SKU123', None, 'September', 15, None, Decimal('0')),
#  ('SKU123', None, 'September', 16, None, Decimal('0')),
#  ('SKU123', None, 'September', 17, None, Decimal('0')),
#  ('SKU123', None, 'September', 18, None, Decimal('0')),
#  ('SKU123', None, 'September', 19, None, Decimal('0')),
#  ('SKU123', None, 'September', 20, None, Decimal('0')),
#  ('SKU123', None, 'September', 21, None, Decimal('0')),
#  ('SKU123', None, 'September', 22, None, Decimal('0')),
#  ('SKU123', None, 'September', 23, None, Decimal('0')),
#  ('SKU123', None, 'September', 24, None, Decimal('0')),
#  ('SKU123', None, 'September', 25, None, Decimal('0')),
#  ('SKU123', None, 'September', 26, None, Decimal('0')),
#  ('SKU123', None, 'September', 27, None, Decimal('0')),
#  ('SKU123', None, 'September', 28, None, Decimal('0')),
#  ('SKU123', None, 'September', 29, None, Decimal('0')),
#  ('SKU123', None, 'September', 30, None, Decimal('0')),
#  ('SKU123', None, 'September', None, None, Decimal('0')),
#  ('SKU123', None, 'October  ', 1, None, Decimal('0')),
#  ('SKU123', None, 'October  ', 2, None, Decimal('0')),
#  ('SKU123', None, 'October  ', 3, None, Decimal('0')),
#  ('SKU123', None, 'October  ', 4, None, Decimal('0')),
#  ('SKU123', None, 'October  ', 5, None, Decimal('0')),
#  ('SKU123', None, 'October  ', 6, None, Decimal('0')),
#  ('SKU123', None, 'October  ', 7, None, Decimal('0')),
#  ('SKU123', None, 'October  ', 8, None, Decimal('0')),
#  ('SKU123', None, 'October  ', 9, None, Decimal('0')),
#  ('SKU123', None, 'October  ', 10, None, Decimal('0')),
#  ('SKU123', None, 'October  ', 11, None, Decimal('0')),
#  ('SKU123', None, 'October  ', 12, None, Decimal('0')),
#  ('SKU123', None, 'October  ', 13, None, Decimal('0')),
#  ('SKU123', None, 'October  ', 14, None, Decimal('0')),
#  ('SKU123', None, 'October  ', 15, None, Decimal('0')),
#  ('SKU123', None, 'October  ', 16, None, Decimal('0')),
#  ('SKU123', None, 'October  ', 17, None, Decimal('0')),
#  ('SKU123', None, 'October  ', 18, None, Decimal('0')),
#  ('SKU123', None, 'October  ', 19, None, Decimal('0')),
#  ('SKU123', None, 'October  ', 20, None, Decimal('0')),
#  ('SKU123', None, 'October  ', 21, None, Decimal('0')),
#  ('SKU123', None, 'October  ', 22, None, Decimal('0')),
#  ('SKU123', None, 'October  ', 23, None, Decimal('0')),
#  ('SKU123', None, 'October  ', 24, None, Decimal('0')),
#  ('SKU123', None, 'October  ', 25, None, Decimal('0')),
#  ('SKU123', None, 'October  ', 26, None, Decimal('0')),
#  ('SKU123', None, 'October  ', 27, None, Decimal('0')),
#  ('SKU123', None, 'October  ', 28, None, Decimal('0')),
#  ('SKU123', None, 'October  ', 29, None, Decimal('0')),
#  ('SKU123', None, 'October  ', 30, None, Decimal('0')),
#  ('SKU123', None, 'October  ', 31, None, Decimal('0')),
#  ('SKU123', None, 'October  ', None, None, Decimal('0')),
#  ('SKU123', None, 'November ', 1, None, Decimal('0')),
#  ('SKU123', None, 'November ', 2, None, Decimal('0')),
#  ('SKU123', None, 'November ', 3, None, Decimal('0')),
#  ('SKU123', None, 'November ', 4, None, Decimal('0')),
#  ('SKU123', None, 'November ', 5, None, Decimal('0')),
#  ('SKU123', None, 'November ', 6, None, Decimal('0')),
#  ('SKU123', None, 'November ', 7, None, Decimal('0')),
#  ('SKU123', None, 'November ', 8, None, Decimal('0')),
#  ('SKU123', None, 'November ', 9, None, Decimal('0')),
#  ('SKU123', None, 'November ', 10, None, Decimal('0')),
#  ('SKU123', None, 'November ', 11, None, Decimal('0')),
#  ('SKU123', None, 'November ', 12, None, Decimal('0')),
#  ('SKU123', None, 'November ', 13, None, Decimal('0')),
#  ('SKU123', None, 'November ', 14, None, Decimal('0')),
#  ('SKU123', None, 'November ', 15, None, Decimal('0')),
#  ('SKU123', None, 'November ', 16, None, Decimal('0')),
#  ('SKU123', None, 'November ', 17, None, Decimal('0')),
#  ('SKU123', None, 'November ', 18, None, Decimal('0')),
#  ('SKU123', None, 'November ', 19, None, Decimal('0')),
#  ('SKU123', None, 'November ', 20, None, Decimal('0')),
#  ('SKU123', None, 'November ', 21, None, Decimal('0')),
#  ('SKU123', None, 'November ', 22, None, Decimal('0')),
#  ('SKU123', None, 'November ', 23, None, Decimal('0')),
#  ('SKU123', None, 'November ', 24, None, Decimal('0')),
#  ('SKU123', None, 'November ', 25, None, Decimal('0')),
#  ('SKU123', None, 'November ', 26, None, Decimal('0')),
#  ('SKU123', None, 'November ', 27, None, Decimal('0')),
#  ('SKU123', None, 'November ', 28, None, Decimal('0')),
#  ('SKU123', None, 'November ', 29, None, Decimal('0')),
#  ('SKU123', None, 'November ', 30, None, Decimal('0')),
#  ('SKU123', None, 'November ', None, None, Decimal('0')),
#  ('SKU123', None, 'December ', 1, None, Decimal('0')),
#  ('SKU123', None, 'December ', 2, None, Decimal('0')),
#  ('SKU123', None, 'December ', 3, None, Decimal('0')),
#  ('SKU123', None, 'December ', 4, None, Decimal('0')),
#  ('SKU123', None, 'December ', 5, None, Decimal('0')),
#  ('SKU123', None, 'December ', 6, None, Decimal('0')),
#  ('SKU123', None, 'December ', 7, None, Decimal('0')),
#  ('SKU123', None, 'December ', 8, None, Decimal('0')),
#  ('SKU123', None, 'December ', 9, None, Decimal('0')),
#  ('SKU123', None, 'December ', 10, None, Decimal('0')),
#  ('SKU123', None, 'December ', 11, None, Decimal('0')),
#  ('SKU123', None, 'December ', 12, None, Decimal('0')),
#  ('SKU123', None, 'December ', 13, None, Decimal('0')),
#  ('SKU123', None, 'December ', 14, None, Decimal('0')),
#  ('SKU123', None, 'December ', 15, None, Decimal('0')),
#  ('SKU123', None, 'December ', 16, None, Decimal('0')),
#  ('SKU123', None, 'December ', 17, None, Decimal('0')),
#  ('SKU123', None, 'December ', 18, None, Decimal('0')),
#  ('SKU123', None, 'December ', 19, None, Decimal('0')),
#  ('SKU123', None, 'December ', 20, None, Decimal('0')),
#  ('SKU123', None, 'December ', 21, None, Decimal('0')),
#  ('SKU123', None, 'December ', 22, None, Decimal('0')),
#  ('SKU123', None, 'December ', 23, None, Decimal('0')),
#  ('SKU123', None, 'December ', 24, None, Decimal('0')),
#  ('SKU123', None, 'December ', 25, None, Decimal('0')),
#  ('SKU123', None, 'December ', 26, None, Decimal('0')),
#  ('SKU123', None, 'December ', 27, None, Decimal('0')),
#  ('SKU123', None, 'December ', 28, None, Decimal('0')),
#  ('SKU123', None, 'December ', 29, None, Decimal('0')),
#  ('SKU123', None, 'December ', 30, None, Decimal('0')),
#  ('SKU123', None, 'December ', 31, None, Decimal('0')),
#  ('SKU123', None, 'December ', None, None, Decimal('0')),
#  ('SKU123', None, None, None, 'Sunday   ', Decimal('0')),
#  ('SKU123', None, None, None, 'Monday   ', Decimal('0')),
#  ('SKU123', None, None, None, 'Tuesday  ', Decimal('0')),
#  ('SKU123', None, None, None, 'Wednesday', Decimal('21.98')),
#  ('SKU123', None, None, None, 'Thursday ', Decimal('0')),
#  ('SKU123', None, None, None, 'Friday   ', Decimal('10.99')),
#  ('SKU123', None, None, None, 'Saturday ', Decimal('0')),
#  ('SKU123', None, None, None, None, Decimal('32.97')),
#  ('SKU123', None, None, None, None, Decimal('0')),
#  ('SKU456', None, 'January  ', 1, None, Decimal('0')),
#  ('SKU456', None, 'January  ', 2, None, Decimal('0')),
#  ('SKU456', None, 'January  ', 3, None, Decimal('0')),
#  ('SKU456', None, 'January  ', 4, None, Decimal('0')),
#  ('SKU456', None, 'January  ', 5, None, Decimal('0')),
#  ('SKU456', None, 'January  ', 6, None, Decimal('0')),
#  ('SKU456', None, 'January  ', 7, None, Decimal('0')),
#  ('SKU456', None, 'January  ', 8, None, Decimal('0')),
#  ('SKU456', None, 'January  ', 9, None, Decimal('0')),
#  ('SKU456', None, 'January  ', 10, None, Decimal('0')),
#  ('SKU456', None, 'January  ', 11, None, Decimal('0')),
#  ('SKU456', None, 'January  ', 12, None, Decimal('0')),
#  ('SKU456', None, 'January  ', 13, None, Decimal('0')),
#  ('SKU456', None, 'January  ', 14, None, Decimal('0')),
#  ('SKU456', None, 'January  ', 15, None, Decimal('0')),
#  ('SKU456', None, 'January  ', 16, None, Decimal('0')),
#  ('SKU456', None, 'January  ', 17, None, Decimal('0')),
#  ('SKU456', None, 'January  ', 18, None, Decimal('0')),
#  ('SKU456', None, 'January  ', 19, None, Decimal('0')),
#  ('SKU456', None, 'January  ', 20, None, Decimal('0')),
#  ('SKU456', None, 'January  ', 21, None, Decimal('0')),
#  ('SKU456', None, 'January  ', 22, None, Decimal('0')),
#  ('SKU456', None, 'January  ', 23, None, Decimal('0')),
#  ('SKU456', None, 'January  ', 24, None, Decimal('0')),
#  ('SKU456', None, 'January  ', 25, None, Decimal('0')),
#  ('SKU456', None, 'January  ', 26, None, Decimal('0')),
#  ('SKU456', None, 'January  ', 27, None, Decimal('0')),
#  ('SKU456', None, 'January  ', 28, None, Decimal('0')),
#  ('SKU456', None, 'January  ', 29, None, Decimal('0')),
#  ('SKU456', None, 'January  ', 30, None, Decimal('0')),
#  ('SKU456', None, 'January  ', 31, None, Decimal('0')),
#  ('SKU456', None, 'January  ', None, None, Decimal('0')),
#  ('SKU456', None, 'February ', 1, None, Decimal('0')),
#  ('SKU456', None, 'February ', 2, None, Decimal('0')),
#  ('SKU456', None, 'February ', 3, None, Decimal('0')),
#  ('SKU456', None, 'February ', 4, None, Decimal('0')),
#  ('SKU456', None, 'February ', 5, None, Decimal('0')),
#  ('SKU456', None, 'February ', 6, None, Decimal('0')),
#  ('SKU456', None, 'February ', 7, None, Decimal('0')),
#  ('SKU456', None, 'February ', 8, None, Decimal('0')),
#  ('SKU456', None, 'February ', 9, None, Decimal('0')),
#  ('SKU456', None, 'February ', 10, None, Decimal('0')),
#  ('SKU456', None, 'February ', 11, None, Decimal('0')),
#  ('SKU456', None, 'February ', 12, None, Decimal('0')),
#  ('SKU456', None, 'February ', 13, None, Decimal('0')),
#  ('SKU456', None, 'February ', 14, None, Decimal('0')),
#  ('SKU456', None, 'February ', 15, None, Decimal('0')),
#  ('SKU456', None, 'February ', 16, None, Decimal('0')),
#  ('SKU456', None, 'February ', 17, None, Decimal('0')),
#  ('SKU456', None, 'February ', 18, None, Decimal('0')),
#  ('SKU456', None, 'February ', 19, None, Decimal('0')),
#  ('SKU456', None, 'February ', 20, None, Decimal('0')),
#  ('SKU456', None, 'February ', 21, None, Decimal('0')),
#  ('SKU456', None, 'February ', 22, None, Decimal('0')),
#  ('SKU456', None, 'February ', 23, None, Decimal('0')),
#  ('SKU456', None, 'February ', 24, None, Decimal('0')),
#  ('SKU456', None, 'February ', 25, None, Decimal('0')),
#  ('SKU456', None, 'February ', 26, None, Decimal('0')),
#  ('SKU456', None, 'February ', 27, None, Decimal('0')),
#  ('SKU456', None, 'February ', 28, None, Decimal('0')),
#  ('SKU456', None, 'February ', None, None, Decimal('0')),
#  ('SKU456', None, 'March    ', 1, None, Decimal('0')),
#  ('SKU456', None, 'March    ', 2, None, Decimal('0')),
#  ('SKU456', None, 'March    ', 3, None, Decimal('0')),
#  ('SKU456', None, 'March    ', 4, None, Decimal('0')),
#  ('SKU456', None, 'March    ', 5, None, Decimal('0')),
#  ('SKU456', None, 'March    ', 6, None, Decimal('0')),
#  ('SKU456', None, 'March    ', 7, None, Decimal('0')),
#  ('SKU456', None, 'March    ', 8, None, Decimal('0')),
#  ('SKU456', None, 'March    ', 9, None, Decimal('0')),
#  ('SKU456', None, 'March    ', 10, None, Decimal('0')),
#  ('SKU456', None, 'March    ', 11, None, Decimal('0')),
#  ('SKU456', None, 'March    ', 12, None, Decimal('0')),
#  ('SKU456', None, 'March    ', 13, None, Decimal('0')),
#  ('SKU456', None, 'March    ', 14, None, Decimal('0')),
#  ('SKU456', None, 'March    ', 15, None, Decimal('0')),
#  ('SKU456', None, 'March    ', 16, None, Decimal('0')),
#  ('SKU456', None, 'March    ', 17, None, Decimal('0')),
#  ('SKU456', None, 'March    ', 18, None, Decimal('0')),
#  ('SKU456', None, 'March    ', 19, None, Decimal('0')),
#  ('SKU456', None, 'March    ', 20, None, Decimal('0')),
#  ('SKU456', None, 'March    ', 21, None, Decimal('0')),
#  ('SKU456', None, 'March    ', 22, None, Decimal('0')),
#  ('SKU456', None, 'March    ', 23, None, Decimal('0')),
#  ('SKU456', None, 'March    ', 24, None, Decimal('0')),
#  ('SKU456', None, 'March    ', 25, None, Decimal('0')),
#  ('SKU456', None, 'March    ', 26, None, Decimal('0')),
#  ('SKU456', None, 'March    ', 27, None, Decimal('0')),
#  ('SKU456', None, 'March    ', 28, None, Decimal('0')),
#  ('SKU456', None, 'March    ', 29, None, Decimal('0')),
#  ('SKU456', None, 'March    ', 30, None, Decimal('0')),
#  ('SKU456', None, 'March    ', 31, None, Decimal('0')),
#  ('SKU456', None, 'March    ', None, None, Decimal('0')),
#  ('SKU456', None, 'April    ', 1, None, Decimal('0')),
#  ('SKU456', None, 'April    ', 2, None, Decimal('0')),
#  ('SKU456', None, 'April    ', 3, None, Decimal('0')),
#  ('SKU456', None, 'April    ', 4, None, Decimal('0')),
#  ('SKU456', None, 'April    ', 5, None, Decimal('0')),
#  ('SKU456', None, 'April    ', 6, None, Decimal('0')),
#  ('SKU456', None, 'April    ', 7, None, Decimal('0')),
#  ('SKU456', None, 'April    ', 8, None, Decimal('0')),
#  ('SKU456', None, 'April    ', 9, None, Decimal('0')),
#  ('SKU456', None, 'April    ', 10, None, Decimal('0')),
#  ('SKU456', None, 'April    ', 11, None, Decimal('0')),
#  ('SKU456', None, 'April    ', 12, None, Decimal('0')),
#  ('SKU456', None, 'April    ', 13, None, Decimal('0')),
#  ('SKU456', None, 'April    ', 14, None, Decimal('0')),
#  ('SKU456', None, 'April    ', 15, None, Decimal('0')),
#  ('SKU456', None, 'April    ', 16, None, Decimal('0')),
#  ('SKU456', None, 'April    ', 17, None, Decimal('0')),
#  ('SKU456', None, 'April    ', 18, None, Decimal('0')),
#  ('SKU456', None, 'April    ', 19, None, Decimal('0')),
#  ('SKU456', None, 'April    ', 20, None, Decimal('0')),
#  ('SKU456', None, 'April    ', 21, None, Decimal('0')),
#  ('SKU456', None, 'April    ', 22, None, Decimal('0')),
#  ('SKU456', None, 'April    ', 23, None, Decimal('0')),
#  ('SKU456', None, 'April    ', 24, None, Decimal('0')),
#  ('SKU456', None, 'April    ', 25, None, Decimal('0')),
#  ('SKU456', None, 'April    ', 26, None, Decimal('0')),
#  ('SKU456', None, 'April    ', 27, None, Decimal('0')),
#  ('SKU456', None, 'April    ', 28, None, Decimal('0')),
#  ('SKU456', None, 'April    ', 29, None, Decimal('0')),
#  ('SKU456', None, 'April    ', 30, None, Decimal('0')),
#  ('SKU456', None, 'April    ', None, None, Decimal('0')),
#  ('SKU456', None, 'May      ', 1, None, Decimal('0')),
#  ('SKU456', None, 'May      ', 2, None, Decimal('0')),
#  ('SKU456', None, 'May      ', 3, None, Decimal('0')),
#  ('SKU456', None, 'May      ', 4, None, Decimal('0')),
#  ('SKU456', None, 'May      ', 5, None, Decimal('0')),
#  ('SKU456', None, 'May      ', 6, None, Decimal('0')),
#  ('SKU456', None, 'May      ', 7, None, Decimal('0')),
#  ('SKU456', None, 'May      ', 8, None, Decimal('0')),
#  ('SKU456', None, 'May      ', 9, None, Decimal('0')),
#  ('SKU456', None, 'May      ', 10, None, Decimal('0')),
#  ('SKU456', None, 'May      ', 11, None, Decimal('0')),
#  ('SKU456', None, 'May      ', 12, None, Decimal('0')),
#  ('SKU456', None, 'May      ', 13, None, Decimal('0')),
#  ('SKU456', None, 'May      ', 14, None, Decimal('0')),
#  ('SKU456', None, 'May      ', 15, None, Decimal('0')),
#  ('SKU456', None, 'May      ', 16, None, Decimal('0')),
#  ('SKU456', None, 'May      ', 17, None, Decimal('0')),
#  ('SKU456', None, 'May      ', 18, None, Decimal('0')),
#  ('SKU456', None, 'May      ', 19, None, Decimal('0')),
#  ('SKU456', None, 'May      ', 20, None, Decimal('0')),
#  ('SKU456', None, 'May      ', 21, None, Decimal('0')),
#  ('SKU456', None, 'May      ', 22, None, Decimal('0')),
#  ('SKU456', None, 'May      ', 23, None, Decimal('0')),
#  ('SKU456', None, 'May      ', 24, None, Decimal('0')),
#  ('SKU456', None, 'May      ', 25, None, Decimal('0')),
#  ('SKU456', None, 'May      ', 26, None, Decimal('0')),
#  ('SKU456', None, 'May      ', 27, None, Decimal('0')),
#  ('SKU456', None, 'May      ', 28, None, Decimal('0')),
#  ('SKU456', None, 'May      ', 29, None, Decimal('0')),
#  ('SKU456', None, 'May      ', 30, None, Decimal('0')),
#  ('SKU456', None, 'May      ', 31, None, Decimal('0')),
#  ('SKU456', None, 'May      ', None, None, Decimal('0')),
#  ('SKU456', None, 'June     ', 1, None, Decimal('0')),
#  ('SKU456', None, 'June     ', 2, None, Decimal('0')),
#  ('SKU456', None, 'June     ', 3, None, Decimal('0')),
#  ('SKU456', None, 'June     ', 4, None, Decimal('0')),
#  ('SKU456', None, 'June     ', 5, None, Decimal('0')),
#  ('SKU456', None, 'June     ', 6, None, Decimal('0')),
#  ('SKU456', None, 'June     ', 7, None, Decimal('0')),
#  ('SKU456', None, 'June     ', 8, None, Decimal('0')),
#  ('SKU456', None, 'June     ', 9, None, Decimal('0')),
#  ('SKU456', None, 'June     ', 10, None, Decimal('0')),
#  ('SKU456', None, 'June     ', 11, None, Decimal('0')),
#  ('SKU456', None, 'June     ', 12, None, Decimal('0')),
#  ('SKU456', None, 'June     ', 13, None, Decimal('0')),
#  ('SKU456', None, 'June     ', 14, None, Decimal('0')),
#  ('SKU456', None, 'June     ', 15, None, Decimal('0')),
#  ('SKU456', None, 'June     ', 16, None, Decimal('0')),
#  ('SKU456', None, 'June     ', 17, None, Decimal('0')),
#  ('SKU456', None, 'June     ', 18, None, Decimal('0')),
#  ('SKU456', None, 'June     ', 19, None, Decimal('0')),
#  ('SKU456', None, 'June     ', 20, None, Decimal('0')),
#  ('SKU456', None, 'June     ', 21, None, Decimal('0')),
#  ('SKU456', None, 'June     ', 22, None, Decimal('0')),
#  ('SKU456', None, 'June     ', 23, None, Decimal('0')),
#  ('SKU456', None, 'June     ', 24, None, Decimal('0')),
#  ('SKU456', None, 'June     ', 25, None, Decimal('0')),
#  ('SKU456', None, 'June     ', 26, None, Decimal('0')),
#  ('SKU456', None, 'June     ', 27, None, Decimal('0')),
#  ('SKU456', None, 'June     ', 28, None, Decimal('0')),
#  ('SKU456', None, 'June     ', 29, None, Decimal('0')),
#  ('SKU456', None, 'June     ', 30, None, Decimal('0')),
#  ('SKU456', None, 'June     ', None, None, Decimal('0')),
#  ('SKU456', None, 'July     ', 1, None, Decimal('0')),
#  ('SKU456', None, 'July     ', 2, None, Decimal('0')),
#  ('SKU456', None, 'July     ', 3, None, Decimal('0')),
#  ('SKU456', None, 'July     ', 4, None, Decimal('0')),
#  ('SKU456', None, 'July     ', 5, None, Decimal('0')),
#  ('SKU456', None, 'July     ', 6, None, Decimal('0')),
#  ('SKU456', None, 'July     ', 7, None, Decimal('0')),
#  ('SKU456', None, 'July     ', 8, None, Decimal('0')),
#  ('SKU456', None, 'July     ', 9, None, Decimal('0')),
#  ('SKU456', None, 'July     ', 10, None, Decimal('0')),
#  ('SKU456', None, 'July     ', 11, None, Decimal('0')),
#  ('SKU456', None, 'July     ', 12, None, Decimal('0')),
#  ('SKU456', None, 'July     ', 13, None, Decimal('0')),
#  ('SKU456', None, 'July     ', 14, None, Decimal('0')),
#  ('SKU456', None, 'July     ', 15, None, Decimal('0')),
#  ('SKU456', None, 'July     ', 16, None, Decimal('0')),
#  ('SKU456', None, 'July     ', 17, None, Decimal('0')),
#  ('SKU456', None, 'July     ', 18, None, Decimal('0')),
#  ('SKU456', None, 'July     ', 19, None, Decimal('0')),
#  ('SKU456', None, 'July     ', 20, None, Decimal('0')),
#  ('SKU456', None, 'July     ', 21, None, Decimal('0')),
#  ('SKU456', None, 'July     ', 22, None, Decimal('0')),
#  ('SKU456', None, 'July     ', 23, None, Decimal('0')),
#  ('SKU456', None, 'July     ', 24, None, Decimal('0')),
#  ('SKU456', None, 'July     ', 25, None, Decimal('0')),
#  ('SKU456', None, 'July     ', 26, None, Decimal('0')),
#  ('SKU456', None, 'July     ', 27, None, Decimal('0')),
#  ('SKU456', None, 'July     ', 28, None, Decimal('0')),
#  ('SKU456', None, 'July     ', 29, None, Decimal('0')),
#  ('SKU456', None, 'July     ', 30, None, Decimal('0')),
#  ('SKU456', None, 'July     ', 31, None, Decimal('0')),
#  ('SKU456', None, 'July     ', None, None, Decimal('0')),
#  ('SKU456', None, 'August   ', 1, None, Decimal('0')),
#  ('SKU456', None, 'August   ', 2, None, Decimal('0')),
#  ('SKU456', None, 'August   ', 3, None, Decimal('0')),
#  ('SKU456', None, 'August   ', 4, None, Decimal('0')),
#  ('SKU456', None, 'August   ', 5, None, Decimal('0')),
#  ('SKU456', None, 'August   ', 6, None, Decimal('0')),
#  ('SKU456', None, 'August   ', 7, None, Decimal('0')),
#  ('SKU456', None, 'August   ', 8, None, Decimal('0')),
#  ('SKU456', None, 'August   ', 9, None, Decimal('0')),
#  ('SKU456', None, 'August   ', 10, None, Decimal('0')),
#  ('SKU456', None, 'August   ', 11, None, Decimal('0')),
#  ('SKU456', None, 'August   ', 12, None, Decimal('0')),
#  ('SKU456', None, 'August   ', 13, None, Decimal('0')),
#  ('SKU456', None, 'August   ', 14, None, Decimal('0')),
#  ('SKU456', None, 'August   ', 15, None, Decimal('0')),
#  ('SKU456', None, 'August   ', 16, None, Decimal('0')),
#  ('SKU456', None, 'August   ', 17, None, Decimal('0')),
#  ('SKU456', None, 'August   ', 18, None, Decimal('0')),
#  ('SKU456', None, 'August   ', 19, None, Decimal('0')),
#  ('SKU456', None, 'August   ', 20, None, Decimal('0')),
#  ('SKU456', None, 'August   ', 21, None, Decimal('0')),
#  ('SKU456', None, 'August   ', 22, None, Decimal('0')),
#  ('SKU456', None, 'August   ', 23, None, Decimal('0')),
#  ('SKU456', None, 'August   ', 24, None, Decimal('0')),
#  ('SKU456', None, 'August   ', 25, None, Decimal('0')),
#  ('SKU456', None, 'August   ', 26, None, Decimal('0')),
#  ('SKU456', None, 'August   ', 27, None, Decimal('0')),
#  ('SKU456', None, 'August   ', 28, None, Decimal('0')),
#  ('SKU456', None, 'August   ', 29, None, Decimal('0')),
#  ('SKU456', None, 'August   ', 30, None, Decimal('0')),
#  ('SKU456', None, 'August   ', 31, None, Decimal('0')),
#  ('SKU456', None, 'August   ', None, None, Decimal('0')),
#  ('SKU456', None, 'September', 1, None, Decimal('0')),
#  ('SKU456', None, 'September', 2, None, Decimal('0')),
#  ('SKU456', None, 'September', 3, None, Decimal('0')),
#  ('SKU456', None, 'September', 4, None, Decimal('0')),
#  ('SKU456', None, 'September', 5, None, Decimal('0')),
#  ('SKU456', None, 'September', 6, None, Decimal('0')),
#  ('SKU456', None, 'September', 7, None, Decimal('0')),
#  ('SKU456', None, 'September', 8, None, Decimal('0')),
#  ('SKU456', None, 'September', 9, None, Decimal('0')),
#  ('SKU456', None, 'September', 10, None, Decimal('0')),
#  ('SKU456', None, 'September', 11, None, Decimal('0')),
#  ('SKU456', None, 'September', 12, None, Decimal('0')),
#  ('SKU456', None, 'September', 13, None, Decimal('0')),
#  ('SKU456', None, 'September', 14, None, Decimal('0')),
#  ('SKU456', None, 'September', 15, None, Decimal('0')),
#  ('SKU456', None, 'September', 16, None, Decimal('0')),
#  ('SKU456', None, 'September', 17, None, Decimal('0')),
#  ('SKU456', None, 'September', 18, None, Decimal('0')),
#  ('SKU456', None, 'September', 19, None, Decimal('0')),
#  ('SKU456', None, 'September', 20, None, Decimal('0')),
#  ('SKU456', None, 'September', 21, None, Decimal('0')),
#  ('SKU456', None, 'September', 22, None, Decimal('0')),
#  ('SKU456', None, 'September', 23, None, Decimal('0')),
#  ('SKU456', None, 'September', 24, None, Decimal('0')),
#  ('SKU456', None, 'September', 25, None, Decimal('0')),
#  ('SKU456', None, 'September', 26, None, Decimal('0')),
#  ('SKU456', None, 'September', 27, None, Decimal('0')),
#  ('SKU456', None, 'September', 28, None, Decimal('0')),
#  ('SKU456', None, 'September', 29, None, Decimal('0')),
#  ('SKU456', None, 'September', 30, None, Decimal('0')),
#  ('SKU456', None, 'September', None, None, Decimal('0')),
#  ('SKU456', None, 'October  ', 1, None, Decimal('0')),
#  ('SKU456', None, 'October  ', 2, None, Decimal('0')),
#  ('SKU456', None, 'October  ', 3, None, Decimal('0')),
#  ('SKU456', None, 'October  ', 4, None, Decimal('0')),
#  ('SKU456', None, 'October  ', 5, None, Decimal('0')),
#  ('SKU456', None, 'October  ', 6, None, Decimal('0')),
#  ('SKU456', None, 'October  ', 7, None, Decimal('0')),
#  ('SKU456', None, 'October  ', 8, None, Decimal('0')),
#  ('SKU456', None, 'October  ', 9, None, Decimal('0')),
#  ('SKU456', None, 'October  ', 10, None, Decimal('0')),
#  ('SKU456', None, 'October  ', 11, None, Decimal('0')),
#  ('SKU456', None, 'October  ', 12, None, Decimal('0')),
#  ('SKU456', None, 'October  ', 13, None, Decimal('0')),
#  ('SKU456', None, 'October  ', 14, None, Decimal('0')),
#  ('SKU456', None, 'October  ', 15, None, Decimal('0')),
#  ('SKU456', None, 'October  ', 16, None, Decimal('0')),
#  ('SKU456', None, 'October  ', 17, None, Decimal('0')),
#  ('SKU456', None, 'October  ', 18, None, Decimal('0')),
#  ('SKU456', None, 'October  ', 19, None, Decimal('0')),
#  ('SKU456', None, 'October  ', 20, None, Decimal('0')),
#  ('SKU456', None, 'October  ', 21, None, Decimal('0')),
#  ('SKU456', None, 'October  ', 22, None, Decimal('0')),
#  ('SKU456', None, 'October  ', 23, None, Decimal('0')),
#  ('SKU456', None, 'October  ', 24, None, Decimal('0')),
#  ('SKU456', None, 'October  ', 25, None, Decimal('0')),
#  ('SKU456', None, 'October  ', 26, None, Decimal('0')),
#  ('SKU456', None, 'October  ', 27, None, Decimal('0')),
#  ('SKU456', None, 'October  ', 28, None, Decimal('0')),
#  ('SKU456', None, 'October  ', 29, None, Decimal('0')),
#  ('SKU456', None, 'October  ', 30, None, Decimal('0')),
#  ('SKU456', None, 'October  ', 31, None, Decimal('0')),
#  ('SKU456', None, 'October  ', None, None, Decimal('0')),
#  ('SKU456', None, 'November ', 1, None, Decimal('0')),
#  ('SKU456', None, 'November ', 2, None, Decimal('0')),
#  ('SKU456', None, 'November ', 3, None, Decimal('0')),
#  ('SKU456', None, 'November ', 4, None, Decimal('0')),
#  ('SKU456', None, 'November ', 5, None, Decimal('0')),
#  ('SKU456', None, 'November ', 6, None, Decimal('0')),
#  ('SKU456', None, 'November ', 7, None, Decimal('0')),
#  ('SKU456', None, 'November ', 8, None, Decimal('0')),
#  ('SKU456', None, 'November ', 9, None, Decimal('0')),
#  ('SKU456', None, 'November ', 10, None, Decimal('0')),
#  ('SKU456', None, 'November ', 11, None, Decimal('0')),
#  ('SKU456', None, 'November ', 12, None, Decimal('0')),
#  ('SKU456', None, 'November ', 13, None, Decimal('0')),
#  ('SKU456', None, 'November ', 14, None, Decimal('0')),
#  ('SKU456', None, 'November ', 15, None, Decimal('0')),
#  ('SKU456', None, 'November ', 16, None, Decimal('0')),
#  ('SKU456', None, 'November ', 17, None, Decimal('0')),
#  ('SKU456', None, 'November ', 18, None, Decimal('0')),
#  ('SKU456', None, 'November ', 19, None, Decimal('0')),
#  ('SKU456', None, 'November ', 20, None, Decimal('0')),
#  ('SKU456', None, 'November ', 21, None, Decimal('0')),
#  ('SKU456', None, 'November ', 22, None, Decimal('0')),
#  ('SKU456', None, 'November ', 23, None, Decimal('0')),
#  ('SKU456', None, 'November ', 24, None, Decimal('0')),
#  ('SKU456', None, 'November ', 25, None, Decimal('0')),
#  ('SKU456', None, 'November ', 26, None, Decimal('0')),
#  ('SKU456', None, 'November ', 27, None, Decimal('0')),
#  ('SKU456', None, 'November ', 28, None, Decimal('0')),
#  ('SKU456', None, 'November ', 29, None, Decimal('0')),
#  ('SKU456', None, 'November ', 30, None, Decimal('0')),
#  ('SKU456', None, 'November ', None, None, Decimal('0')),
#  ('SKU456', None, 'December ', 1, None, Decimal('0')),
#  ('SKU456', None, 'December ', 2, None, Decimal('0')),
#  ('SKU456', None, 'December ', 3, None, Decimal('0')),
#  ('SKU456', None, 'December ', 4, None, Decimal('0')),
#  ('SKU456', None, 'December ', 5, None, Decimal('0')),
#  ('SKU456', None, 'December ', 6, None, Decimal('0')),
#  ('SKU456', None, 'December ', 7, None, Decimal('0')),
#  ('SKU456', None, 'December ', 8, None, Decimal('0')),
#  ('SKU456', None, 'December ', 9, None, Decimal('0')),
#  ('SKU456', None, 'December ', 10, None, Decimal('0')),
#  ('SKU456', None, 'December ', 11, None, Decimal('0')),
#  ('SKU456', None, 'December ', 12, None, Decimal('0')),
#  ('SKU456', None, 'December ', 13, None, Decimal('0')),
#  ('SKU456', None, 'December ', 14, None, Decimal('0')),
#  ('SKU456', None, 'December ', 15, None, Decimal('0')),
#  ('SKU456', None, 'December ', 16, None, Decimal('0')),
#  ('SKU456', None, 'December ', 17, None, Decimal('0')),
#  ('SKU456', None, 'December ', 18, None, Decimal('0')),
#  ('SKU456', None, 'December ', 19, None, Decimal('0')),
#  ('SKU456', None, 'December ', 20, None, Decimal('0')),
#  ('SKU456', None, 'December ', 21, None, Decimal('0')),
#  ('SKU456', None, 'December ', 22, None, Decimal('0')),
#  ('SKU456', None, 'December ', 23, None, Decimal('0')),
#  ('SKU456', None, 'December ', 24, None, Decimal('0')),
#  ('SKU456', None, 'December ', 25, None, Decimal('0')),
#  ('SKU456', None, 'December ', 26, None, Decimal('0')),
#  ('SKU456', None, 'December ', 27, None, Decimal('0')),
#  ('SKU456', None, 'December ', 28, None, Decimal('0')),
#  ('SKU456', None, 'December ', 29, None, Decimal('0')),
#  ('SKU456', None, 'December ', 30, None, Decimal('0')),
#  ('SKU456', None, 'December ', 31, None, Decimal('0')),
#  ('SKU456', None, 'December ', None, None, Decimal('0')),
#  ('SKU456', None, None, None, 'Sunday   ', Decimal('0')),
#  ('SKU456', None, None, None, 'Monday   ', Decimal('0')),
#  ('SKU456', None, None, None, 'Tuesday  ', Decimal('0')),
#  ('SKU456', None, None, None, 'Wednesday', Decimal('0')),
#  ('SKU456', None, None, None, 'Thursday ', Decimal('0')),
#  ('SKU456', None, None, None, 'Friday   ', Decimal('0')),
#  ('SKU456', None, None, None, 'Saturday ', Decimal('0')),
#  ('SKU456', None, None, None, None, Decimal('0')),
#  ('SKU456', None, None, None, None, Decimal('0')),
#  ('SKU789', 'Lisboa', None, None, None, Decimal('17.97')),
#  ('SKU789', None, 'January  ', 1, None, Decimal('0')),
#  ('SKU789', None, 'January  ', 2, None, Decimal('0')),
#  ('SKU789', None, 'January  ', 3, None, Decimal('0')),
#  ('SKU789', None, 'January  ', 4, None, Decimal('0')),
#  ('SKU789', None, 'January  ', 5, None, Decimal('0')),
#  ('SKU789', None, 'January  ', 6, None, Decimal('0')),
#  ('SKU789', None, 'January  ', 7, None, Decimal('0')),
#  ('SKU789', None, 'January  ', 8, None, Decimal('0')),
#  ('SKU789', None, 'January  ', 9, None, Decimal('0')),
#  ('SKU789', None, 'January  ', 10, None, Decimal('0')),
#  ('SKU789', None, 'January  ', 11, None, Decimal('0')),
#  ('SKU789', None, 'January  ', 12, None, Decimal('0')),
#  ('SKU789', None, 'January  ', 13, None, Decimal('0')),
#  ('SKU789', None, 'January  ', 14, None, Decimal('0')),
#  ('SKU789', None, 'January  ', 15, None, Decimal('0')),
#  ('SKU789', None, 'January  ', 16, None, Decimal('0')),
#  ('SKU789', None, 'January  ', 17, None, Decimal('0')),
#  ('SKU789', None, 'January  ', 18, None, Decimal('0')),
#  ('SKU789', None, 'January  ', 19, None, Decimal('0')),
#  ('SKU789', None, 'January  ', 20, None, Decimal('0')),
#  ('SKU789', None, 'January  ', 21, None, Decimal('0')),
#  ('SKU789', None, 'January  ', 22, None, Decimal('0')),
#  ('SKU789', None, 'January  ', 23, None, Decimal('0')),
#  ('SKU789', None, 'January  ', 24, None, Decimal('0')),
#  ('SKU789', None, 'January  ', 25, None, Decimal('0')),
#  ('SKU789', None, 'January  ', 26, None, Decimal('0')),
#  ('SKU789', None, 'January  ', 27, None, Decimal('0')),
#  ('SKU789', None, 'January  ', 28, None, Decimal('0')),
#  ('SKU789', None, 'January  ', 29, None, Decimal('0')),
#  ('SKU789', None, 'January  ', 30, None, Decimal('0')),
#  ('SKU789', None, 'January  ', 31, None, Decimal('0')),
#  ('SKU789', None, 'January  ', None, None, Decimal('0')),
#  ('SKU789', None, 'February ', 1, None, Decimal('0')),
#  ('SKU789', None, 'February ', 2, None, Decimal('0')),
#  ('SKU789', None, 'February ', 3, None, Decimal('0')),
#  ('SKU789', None, 'February ', 4, None, Decimal('0')),
#  ('SKU789', None, 'February ', 5, None, Decimal('0')),
#  ('SKU789', None, 'February ', 6, None, Decimal('0')),
#  ('SKU789', None, 'February ', 7, None, Decimal('0')),
#  ('SKU789', None, 'February ', 8, None, Decimal('0')),
#  ('SKU789', None, 'February ', 9, None, Decimal('0')),
#  ('SKU789', None, 'February ', 10, None, Decimal('0')),
#  ('SKU789', None, 'February ', 11, None, Decimal('0')),
#  ('SKU789', None, 'February ', 12, None, Decimal('0')),
#  ('SKU789', None, 'February ', 13, None, Decimal('0')),
#  ('SKU789', None, 'February ', 14, None, Decimal('0')),
#  ('SKU789', None, 'February ', 15, None, Decimal('0')),
#  ('SKU789', None, 'February ', 16, None, Decimal('0')),
#  ('SKU789', None, 'February ', 17, None, Decimal('0')),
#  ('SKU789', None, 'February ', 18, None, Decimal('0')),
#  ('SKU789', None, 'February ', 19, None, Decimal('0')),
#  ('SKU789', None, 'February ', 20, None, Decimal('0')),
#  ('SKU789', None, 'February ', 21, None, Decimal('0')),
#  ('SKU789', None, 'February ', 22, None, Decimal('0')),
#  ('SKU789', None, 'February ', 23, None, Decimal('0')),
#  ('SKU789', None, 'February ', 24, None, Decimal('0')),
#  ('SKU789', None, 'February ', 25, None, Decimal('0')),
#  ('SKU789', None, 'February ', 26, None, Decimal('0')),
#  ('SKU789', None, 'February ', 27, None, Decimal('0')),
#  ('SKU789', None, 'February ', 28, None, Decimal('0')),
#  ('SKU789', None, 'February ', None, None, Decimal('0')),
#  ('SKU789', None, 'March    ', 1, None, Decimal('0')),
#  ('SKU789', None, 'March    ', 2, None, Decimal('0')),
#  ('SKU789', None, 'March    ', 3, None, Decimal('0')),
#  ('SKU789', None, 'March    ', 4, None, Decimal('0')),
#  ('SKU789', None, 'March    ', 5, None, Decimal('0')),
#  ('SKU789', None, 'March    ', 6, None, Decimal('0')),
#  ('SKU789', None, 'March    ', 7, None, Decimal('0')),
#  ('SKU789', None, 'March    ', 8, None, Decimal('0')),
#  ('SKU789', None, 'March    ', 9, None, Decimal('0')),
#  ('SKU789', None, 'March    ', 10, None, Decimal('0')),
#  ('SKU789', None, 'March    ', 11, None, Decimal('0')),
#  ('SKU789', None, 'March    ', 12, None, Decimal('0')),
#  ('SKU789', None, 'March    ', 13, None, Decimal('0')),
#  ('SKU789', None, 'March    ', 14, None, Decimal('0')),
#  ('SKU789', None, 'March    ', 15, None, Decimal('0')),
#  ('SKU789', None, 'March    ', 16, None, Decimal('0')),
#  ('SKU789', None, 'March    ', 17, None, Decimal('0')),
#  ('SKU789', None, 'March    ', 18, None, Decimal('0')),
#  ('SKU789', None, 'March    ', 19, None, Decimal('0')),
#  ('SKU789', None, 'March    ', 20, None, Decimal('0')),
#  ('SKU789', None, 'March    ', 21, None, Decimal('0')),
#  ('SKU789', None, 'March    ', 22, None, Decimal('0')),
#  ('SKU789', None, 'March    ', 23, None, Decimal('0')),
#  ('SKU789', None, 'March    ', 24, None, Decimal('0')),
#  ('SKU789', None, 'March    ', 25, None, Decimal('0')),
#  ('SKU789', None, 'March    ', 26, None, Decimal('0')),
#  ('SKU789', None, 'March    ', 27, None, Decimal('0')),
#  ('SKU789', None, 'March    ', 28, None, Decimal('0')),
#  ('SKU789', None, 'March    ', 29, None, Decimal('0')),
#  ('SKU789', None, 'March    ', 30, None, Decimal('0')),
#  ('SKU789', None, 'March    ', 31, None, Decimal('0')),
#  ('SKU789', None, 'March    ', None, None, Decimal('0')),
#  ('SKU789', None, 'April    ', 1, None, Decimal('0')),
#  ('SKU789', None, 'April    ', 2, None, Decimal('0')),
#  ('SKU789', None, 'April    ', 3, None, Decimal('0')),
#  ('SKU789', None, 'April    ', 4, None, Decimal('0')),
#  ('SKU789', None, 'April    ', 5, None, Decimal('0')),
#  ('SKU789', None, 'April    ', 6, None, Decimal('0')),
#  ('SKU789', None, 'April    ', 7, None, Decimal('0')),
#  ('SKU789', None, 'April    ', 8, None, Decimal('0')),
#  ('SKU789', None, 'April    ', 9, None, Decimal('0')),
#  ('SKU789', None, 'April    ', 10, None, Decimal('0')),
#  ('SKU789', None, 'April    ', 11, None, Decimal('0')),
#  ('SKU789', None, 'April    ', 12, None, Decimal('0')),
#  ('SKU789', None, 'April    ', 13, None, Decimal('0')),
#  ('SKU789', None, 'April    ', 14, None, Decimal('0')),
#  ('SKU789', None, 'April    ', 15, None, Decimal('0')),
#  ('SKU789', None, 'April    ', 16, None, Decimal('0')),
#  ('SKU789', None, 'April    ', 17, None, Decimal('0')),
#  ('SKU789', None, 'April    ', 18, None, Decimal('0')),
#  ('SKU789', None, 'April    ', 19, None, Decimal('0')),
#  ('SKU789', None, 'April    ', 20, None, Decimal('0')),
#  ('SKU789', None, 'April    ', 21, None, Decimal('0')),
#  ('SKU789', None, 'April    ', 22, None, Decimal('0')),
#  ('SKU789', None, 'April    ', 23, None, Decimal('0')),
#  ('SKU789', None, 'April    ', 24, None, Decimal('0')),
#  ('SKU789', None, 'April    ', 25, None, Decimal('0')),
#  ('SKU789', None, 'April    ', 26, None, Decimal('0')),
#  ('SKU789', None, 'April    ', 27, None, Decimal('0')),
#  ('SKU789', None, 'April    ', 28, None, Decimal('0')),
#  ('SKU789', None, 'April    ', 29, None, Decimal('0')),
#  ('SKU789', None, 'April    ', 30, None, Decimal('0')),
#  ('SKU789', None, 'April    ', None, None, Decimal('0')),
#  ('SKU789', None, 'May      ', 1, None, Decimal('0')),
#  ('SKU789', None, 'May      ', 2, None, Decimal('0')),
#  ('SKU789', None, 'May      ', 3, None, Decimal('0')),
#  ('SKU789', None, 'May      ', 4, None, Decimal('0')),
#  ('SKU789', None, 'May      ', 5, None, Decimal('0')),
#  ('SKU789', None, 'May      ', 6, None, Decimal('0')),
#  ('SKU789', None, 'May      ', 7, None, Decimal('0')),
#  ('SKU789', None, 'May      ', 8, None, Decimal('0')),
#  ('SKU789', None, 'May      ', 9, None, Decimal('0')),
#  ('SKU789', None, 'May      ', 10, None, Decimal('0')),
#  ('SKU789', None, 'May      ', 11, None, Decimal('0')),
#  ('SKU789', None, 'May      ', 12, None, Decimal('0')),
#  ('SKU789', None, 'May      ', 13, None, Decimal('0')),
#  ('SKU789', None, 'May      ', 14, None, Decimal('0')),
#  ('SKU789', None, 'May      ', 15, None, Decimal('0')),
#  ('SKU789', None, 'May      ', 16, None, Decimal('0')),
#  ('SKU789', None, 'May      ', 17, None, Decimal('0')),
#  ('SKU789', None, 'May      ', 18, None, Decimal('0')),
#  ('SKU789', None, 'May      ', 19, None, Decimal('0')),
#  ('SKU789', None, 'May      ', 20, None, Decimal('0')),
#  ('SKU789', None, 'May      ', 21, None, Decimal('0')),
#  ('SKU789', None, 'May      ', 22, None, Decimal('0')),
#  ('SKU789', None, 'May      ', 23, None, Decimal('0')),
#  ('SKU789', None, 'May      ', 24, None, Decimal('0')),
#  ('SKU789', None, 'May      ', 25, None, Decimal('0')),
#  ('SKU789', None, 'May      ', 26, None, Decimal('0')),
#  ('SKU789', None, 'May      ', 27, None, Decimal('0')),
#  ('SKU789', None, 'May      ', 28, None, Decimal('0')),
#  ('SKU789', None, 'May      ', 29, None, Decimal('0')),
#  ('SKU789', None, 'May      ', 30, None, Decimal('0')),
#  ('SKU789', None, 'May      ', 31, None, Decimal('0')),
#  ('SKU789', None, 'May      ', None, None, Decimal('0')),
#  ('SKU789', None, 'June     ', 1, None, Decimal('0')),
#  ('SKU789', None, 'June     ', 2, None, Decimal('17.97')),
#  ('SKU789', None, 'June     ', 3, None, Decimal('0')),
#  ('SKU789', None, 'June     ', 4, None, Decimal('0')),
#  ('SKU789', None, 'June     ', 5, None, Decimal('0')),
#  ('SKU789', None, 'June     ', 6, None, Decimal('0')),
#  ('SKU789', None, 'June     ', 7, None, Decimal('0')),
#  ('SKU789', None, 'June     ', 8, None, Decimal('0')),
#  ('SKU789', None, 'June     ', 9, None, Decimal('0')),
#  ('SKU789', None, 'June     ', 10, None, Decimal('0')),
#  ('SKU789', None, 'June     ', 11, None, Decimal('0')),
#  ('SKU789', None, 'June     ', 12, None, Decimal('0')),
#  ('SKU789', None, 'June     ', 13, None, Decimal('0')),
#  ('SKU789', None, 'June     ', 14, None, Decimal('0')),
#  ('SKU789', None, 'June     ', 15, None, Decimal('0')),
#  ('SKU789', None, 'June     ', 16, None, Decimal('0')),
#  ('SKU789', None, 'June     ', 17, None, Decimal('0')),
#  ('SKU789', None, 'June     ', 18, None, Decimal('0')),
#  ('SKU789', None, 'June     ', 19, None, Decimal('0')),
#  ('SKU789', None, 'June     ', 20, None, Decimal('0')),
#  ('SKU789', None, 'June     ', 21, None, Decimal('0')),
#  ('SKU789', None, 'June     ', 22, None, Decimal('0')),
#  ('SKU789', None, 'June     ', 23, None, Decimal('0')),
#  ('SKU789', None, 'June     ', 24, None, Decimal('0')),
#  ('SKU789', None, 'June     ', 25, None, Decimal('0')),
#  ('SKU789', None, 'June     ', 26, None, Decimal('0')),
#  ('SKU789', None, 'June     ', 27, None, Decimal('0')),
#  ('SKU789', None, 'June     ', 28, None, Decimal('0')),
#  ('SKU789', None, 'June     ', 29, None, Decimal('0')),
#  ('SKU789', None, 'June     ', 30, None, Decimal('0')),
#  ('SKU789', None, 'June     ', None, None, Decimal('17.97')),
#  ('SKU789', None, 'July     ', 1, None, Decimal('0')),
#  ('SKU789', None, 'July     ', 2, None, Decimal('0')),
#  ('SKU789', None, 'July     ', 3, None, Decimal('0')),
#  ('SKU789', None, 'July     ', 4, None, Decimal('0')),
#  ('SKU789', None, 'July     ', 5, None, Decimal('0')),
#  ('SKU789', None, 'July     ', 6, None, Decimal('0')),
#  ('SKU789', None, 'July     ', 7, None, Decimal('0')),
#  ('SKU789', None, 'July     ', 8, None, Decimal('0')),
#  ('SKU789', None, 'July     ', 9, None, Decimal('0')),
#  ('SKU789', None, 'July     ', 10, None, Decimal('0')),
#  ('SKU789', None, 'July     ', 11, None, Decimal('0')),
#  ('SKU789', None, 'July     ', 12, None, Decimal('0')),
#  ('SKU789', None, 'July     ', 13, None, Decimal('0')),
#  ('SKU789', None, 'July     ', 14, None, Decimal('0')),
#  ('SKU789', None, 'July     ', 15, None, Decimal('0')),
#  ('SKU789', None, 'July     ', 16, None, Decimal('0')),
#  ('SKU789', None, 'July     ', 17, None, Decimal('0')),
#  ('SKU789', None, 'July     ', 18, None, Decimal('0')),
#  ('SKU789', None, 'July     ', 19, None, Decimal('0')),
#  ('SKU789', None, 'July     ', 20, None, Decimal('0')),
#  ('SKU789', None, 'July     ', 21, None, Decimal('0')),
#  ('SKU789', None, 'July     ', 22, None, Decimal('0')),
#  ('SKU789', None, 'July     ', 23, None, Decimal('0')),
#  ('SKU789', None, 'July     ', 24, None, Decimal('0')),
#  ('SKU789', None, 'July     ', 25, None, Decimal('0')),
#  ('SKU789', None, 'July     ', 26, None, Decimal('0')),
#  ('SKU789', None, 'July     ', 27, None, Decimal('0')),
#  ('SKU789', None, 'July     ', 28, None, Decimal('0')),
#  ('SKU789', None, 'July     ', 29, None, Decimal('0')),
#  ('SKU789', None, 'July     ', 30, None, Decimal('0')),
#  ('SKU789', None, 'July     ', 31, None, Decimal('0')),
#  ('SKU789', None, 'July     ', None, None, Decimal('0')),
#  ('SKU789', None, 'August   ', 1, None, Decimal('0')),
#  ('SKU789', None, 'August   ', 2, None, Decimal('0')),
#  ('SKU789', None, 'August   ', 3, None, Decimal('0')),
#  ('SKU789', None, 'August   ', 4, None, Decimal('0')),
#  ('SKU789', None, 'August   ', 5, None, Decimal('0')),
#  ('SKU789', None, 'August   ', 6, None, Decimal('0')),
#  ('SKU789', None, 'August   ', 7, None, Decimal('0')),
#  ...]

# %% [markdown]
# 2. O valor médio diário das vendas de todos os produtos em 2022, globalmente, por mês e dia da semana

# %%
# %%sql
# SELECT sku, AVG(total_price) AS avg_price,month,day_of_week
# FROM product_sales
# WHERE year=2022
# GROUP BY GROUPING SETS((sku,month), (sku,day_of_week), ())
# ORDER BY sku,avg_price,month,day_of_week ASC;
# Out:
# *  postgresql://p3:***@postgres/p3
# 5 rows affected.
# [('SKU123', Decimal('10.9900000000000000'), 'June     ', None),
#  ('SKU123', Decimal('10.9900000000000000'), None, 'Friday   '),
#  ('SKU789', Decimal('17.9700000000000000'), 'June     ', None),
#  ('SKU789', Decimal('17.9700000000000000'), None, 'Thursday '),
#  (None, Decimal('14.4800000000000000'), None, None)]

# %% [markdown]
# ## 6. Índices

# %% [markdown]
# Indique, com a devida justificação, que tipo de índice(s), sobre qual(is) atributo(s) e sobre qual(is) tabela(s) faria sentido criar, de forma a agilizar a execução de cada uma das seguintes consultas:

# %% [markdown]
# ### 6.1
# SELECT order_no
# FROM orders
# JOIN contains USING (order_no)
# JOIN product USING (SKU)
# WHERE price > 50 AND
# EXTRACT(YEAR FROM date) = 2023

# %% [markdown]
# ### Tipo de Índice, Atributos & Justificação
#
# ...

# %% [markdown]
# ### 6.2
# SELECT order_no, SUM(qty*price)
# FROM contains
# JOIN product USING (SKU)
# WHERE name LIKE ‘A%’
# GROUP BY order_no;

# %% [markdown]
# ### Tipo de Índice, Atributos & Justificação
#
# ...
